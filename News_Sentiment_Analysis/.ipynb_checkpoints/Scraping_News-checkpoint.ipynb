# %%
# import required libraries for scraping
from urllib.request import urlopen, Request
# !pip install bs4
from bs4 import BeautifulSoup
import pandas as pd
import os
import csv

#import required libraries for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,6)
# !pip install wordcloud
from wordcloud import WordCloud, STOPWORDS
# Out:
# Requirement already satisfied: bs4 in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Requirement already satisfied: wordcloud in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from wordcloud) (1.18.5)
# Requirement already satisfied: matplotlib in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: pillow in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from wordcloud) (8.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: six in c:\users\tanyadyne\anaconda3\envs\sentimenttrading\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# Because the FINVIZ website only shows as many articles as the page can fit, we may not start out with enough articles
# collected (per ticker). For use in the future, we may then want to scrape the website and then save that data as a .csv file. That means that (in the future) we can run sentiment analysis on a longer timeframe of our choosing (e.g. over one month rather than over 5 days).

# %%
# scrape article titles from FINVIZ
finviz_url = 'https://finviz.com/quote.ashx?t='                      # the common factor of all ticker urls
tickers = ['TSLA', 'AAPL', 'FB']

news_tables = {}                                                     # dictionary to store news data found in a table within
                                                                     # the source code

for ticker in tickers:
    url = finviz_url + ticker                                        # specify url format
    req = Request(url=url, headers={'user-agent': 'my-app'})         # verify user access
    response = urlopen(req)                                          # open the request
    
    html = BeautifulSoup(response, 'html')                           # mention html parser 
    news_table = html.find(id='news-table')                          # retrieve html object of the news table
    news_tables[ticker] = news_table                                 # store data by key 'ticker'

# %%
# for testing purposes
# os.remove("finvizData.csv")

# %%
# specify header row
header = ['Ticker','Date','Time','News_Title']                        

# create new csv file if doesn't exist
if not os.path.isfile('./finvizData.csv'):
    with open ('finvizData.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(i for i in header) 

# start appending new data to the file
with open('finvizData.csv', 'a', newline='', encoding="cp1252") as f:
    writer = csv.writer(f)
    for ticker, news_table in news_tables.items():                    # iterate over key, value pairs in news_tables
    
        for row in news_table.findAll('tr'):                             
        
            title = row.a.text                                        # get title of the news article by tag 'a'
            date_data = row.td.text.split(' ')                        # get date data by tag 'td' + split by 'space'
    
            if len(date_data) == 1:                                   # split the date_data to retrieve both time and date
                time = date_data[0].replace('\xa0\xa0', '')
            else:
                date = date_data[0]
                time = date_data[1].replace('\xa0\xa0', '')
            
            entry = [ticker, date, time, title]
            
            writer.writerow(entry)                                    # only write row if entry not in seen()

# remove duplicates and send back to the same file            
data = pd.read_csv('./finvizData.csv', encoding='cp1252')             # cp1252 encoding required for consistency
data.drop_duplicates(inplace=True)
data.to_csv('./finvizData.csv', index=False, encoding='cp1252')       
            
    
print(f'Data has been scraped. There are {len(data)} rows.') 
            
    
# 12/09/21 - 301 rows incl header (in csv file, but jupyter will say 300 rows)
# Out:
# Data has been scraped. There are 300 rows.

# %%
# import dependencies for sentiment analysis using the neural network I created in ./Natural_Language_Classification
import tensorflow as tf
import numpy as np
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# load data from csv file into dataframe
df = pd.read_csv('finvizData.csv', encoding = 'cp1252')      
df
# Out:
#     Ticker       Date     Time  \
# 0     TSLA  Sep-12-21  12:24AM
# 1     TSLA  Sep-11-21  08:28PM
# 2     TSLA  Sep-11-21  09:08AM
# 3     TSLA  Sep-11-21  04:00AM
# 4     TSLA  Sep-10-21  09:45PM
# ..     ...        ...      ...
# 295     FB  Sep-01-21  06:29PM
# 296     FB  Sep-01-21  04:47PM
# 297     FB  Sep-01-21  04:28PM
# 298     FB  Sep-01-21  04:18PM
# 299     FB  Sep-01-21  04:15PM
#
#                                             News_Title
# 0    Dow Jones Futures: Market Rally Retreats Amid ...
# 1    UPDATE 1-Toyota, Honda oppose U.S. House elect...
# 2             3 Top Robinhood Stocks Wall Street Loves
# 3    EV Checkpoint: Cramer Says Ford Hired Apple Ex...
# 4    5 Best Chinese Stocks To Buy And Watch As Beij...
# ..                                                 ...
# 295      Why Facebook Pays Shopify Integration Matters
# 296  U.S. DOJ Readying Google Antitrust Lawsuit Ove...
# 297  Facebook Stock Gets a Downgrade. Watch the Thr...
# 298  Why Facebook Stock Dropped This Morning, but A...
# 299  Elizabeth Warren Urges Justice Department to I...
#
# [300 rows x 4 columns]

# %%
# load tokenizer
with open('./tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# load model
model = tf.keras.models.load_model('./model_1')

# %%
# set variables
oov_tok = '<OOV>'
padding_type = 'post'
trunc_type = 'post'
vocab_size = 1000
max_length = 142

# create function so that we can mass-preprocess the sentences (news titles)
def preprocessText(text):
    sequences = tokenizer.texts_to_sequences(text)
    padded = pad_sequences(sequences,
                           maxlen=max_length,
                           padding=padding_type,
                           truncating=trunc_type)
    return padded

# preprocess entire 'News Title' column
prep = preprocessText(df['News_Title'])

# %%
# implement sentiment prediction on our scraped data
prep = model.predict(prep)
prep[:10]
# Out:
# array([[0.17739215, 0.34629798, 0.47630984],
#        [0.14471175, 0.3767821 , 0.47850615],
#        [0.31796917, 0.24342261, 0.4386082 ],
#        [0.06795865, 0.4714344 , 0.460607  ],
#        [0.0653277 , 0.47739896, 0.4572733 ],
#        [0.07967422, 0.45266575, 0.46765998],
#        [0.151807  , 0.36837715, 0.47981578],
#        [0.0426607 , 0.5233756 , 0.43396375],
#        [0.2709011 , 0.27324662, 0.45585227],
#        [0.35602573, 0.2219635 , 0.42201075]], dtype=float32)

# %%
# create a new column that stores the predicted sentiment
df['Sentiment'] = np.argmax(prep, axis = -1)
df
# Out:
#     Ticker       Date     Time  \
# 0     TSLA  Sep-12-21  12:24AM
# 1     TSLA  Sep-11-21  08:28PM
# 2     TSLA  Sep-11-21  09:08AM
# 3     TSLA  Sep-11-21  04:00AM
# 4     TSLA  Sep-10-21  09:45PM
# ..     ...        ...      ...
# 295     FB  Sep-01-21  06:29PM
# 296     FB  Sep-01-21  04:47PM
# 297     FB  Sep-01-21  04:28PM
# 298     FB  Sep-01-21  04:18PM
# 299     FB  Sep-01-21  04:15PM
#
#                                             News_Title  Sentiment
# 0    Dow Jones Futures: Market Rally Retreats Amid ...          2
# 1    UPDATE 1-Toyota, Honda oppose U.S. House elect...          2
# 2             3 Top Robinhood Stocks Wall Street Loves          2
# 3    EV Checkpoint: Cramer Says Ford Hired Apple Ex...          1
# 4    5 Best Chinese Stocks To Buy And Watch As Beij...          1
# ..                                                 ...        ...
# 295      Why Facebook Pays Shopify Integration Matters          2
# 296  U.S. DOJ Readying Google Antitrust Lawsuit Ove...          1
# 297  Facebook Stock Gets a Downgrade. Watch the Thr...          2
# 298  Why Facebook Stock Dropped This Morning, but A...          2
# 299  Elizabeth Warren Urges Justice Department to I...          1
#
# [300 rows x 5 columns]

# %% [markdown]
# #### Some examples:
# (note that 0:Negative, 1:Neutral, 2:Positive)

# %%
df.iloc[90]
# Out:
# Ticker                                                     TSLA
# Date                                                  Sep-05-21
# Time                                                    10:46AM
# News_Title    Ark Invest Tesla Stock Price Target May Be Out...
# Sentiment                                                     1
# Name: 90, dtype: object

# %%
df.iloc[15]
# Out:
# Ticker                                               TSLA
# Date                                            Sep-10-21
# Time                                              08:10AM
# News_Title    Why This Pricey Growth Stock Is a Smart Buy
# Sentiment                                               1
# Name: 15, dtype: object

# %%
df.iloc[210]
# Out:
# Ticker                                                       FB
# Date                                                  Sep-10-21
# Time                                                    10:43AM
# News_Title    Best Mutual Funds Betting Billions On Microsof...
# Sentiment                                                     2
# Name: 210, dtype: object

# %%
df.iloc[170]
# Out:
# Ticker                                                     AAPL
# Date                                                  Sep-09-21
# Time                                                    09:36PM
# News_Title    UPDATE 2-Apple rebuffs Epic request to restore...
# Sentiment                                                     2
# Name: 170, dtype: object

# %% [markdown]
# #### A Potential Flaw?
# In the barchart below, we can see that the results are heavily skewed towards a positive sentiment. Whilst this does not inherently imply that my model has not performed well, it does concern me that the model may have some statistical bias. Some initial solutions that come to mind are the need for a larger training dataset as well as a longer timeframe for for the articles to span.

# %%
# create bar chart to visualise sentiment count
df['Sentiment'].value_counts().plot(kind='barh', color=['green','grey','red'])
plt.title('Sentiment Count', fontsize=20)
plt.xlabel('Number of Articles', fontsize=12)
plt.ylabel('Sentiment', fontsize=12)

# creating legend 
red_patch = mpatches.Patch(color='red', label='Negative')
grey_patch = mpatches.Patch(color='grey', label='Neutral')
green_patch = mpatches.Patch(color='green', label='Positive')
plt.legend(handles=[red_patch, grey_patch, green_patch])
plt.show()

# %%
# function for wordcloud generation
def wordcount_cloud(df, sentiment):
    '''
    Generates word cloud
    inputs:
        - df (the scraped news headlines)
        - sentiment (positive/negative/neutral)
    '''
    # combine text by sentiment category
    comb_text = " ".join([title for title in df[df['Sentiment']==sentiment]['News_Title']])
    
    # assigning sentiment values
    if sentiment == 0:
        x = 'Negative'
    elif sentiment == 1:
        x = 'Neutral'
    else:
        x = 'Positive'
    
    # adding additional stopwords
    stop_words = ['Tesla', 'Apple', 'Facebook', 'Stock', 'Stocks'] + list(STOPWORDS)
    
    # generate and plot wordcloud
    wc = WordCloud(background_color='white',
                   max_words=50,
                   stopwords=stop_words,
                   height=300,
                   width=300)
    
    plt.imshow(wc.generate(comb_text))
    plt.title(f'{x} words', fontsize=20)
    plt.axis('off')
    plt.show
    
wordcount_cloud(df, 0)

# %%
wordcount_cloud(df, 1)

# %%
wordcount_cloud(df, 2)
